# %%
# %run "/mnt/c/Users/ponc892/OneDrive - PNNL/Documents/Python_Files/CU-Boulder_NIST/bcqt-ctrl/pna_control/tone_finder.py"
# Out:
# Order	Index	Freq [GHz]
# 0	67	3.00067
# 1	8479	3.08479
# 2	50049	3.50049
# 3	62418	3.62418
# 4	83557	3.83557
# 5	86232	3.86232
# 6	117836	4.17836
# 7	138002	4.38002
# 8	140345	4.40345
# 9	145991	4.45991
# 10	150395	4.50395
# 11	244743	5.44743
# 12	299338	5.99338
# 13	331725	6.31725
# 14	341030	6.4103
# 15	376973	6.76973
# 16	383007	6.83007
# 17	436192	7.36192
# 18	456107	7.56107
