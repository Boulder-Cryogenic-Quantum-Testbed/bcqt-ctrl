# %%
# %run CryoSwitchController

switch = Cryoswitch(IP='192.168.0.117') ## -> CryoSwitch class declaration and USB connection

switch.start() ## -> Initialization of the internal hardware

switch.get_internal_temperature()
switch.get_pulse_history(pulse_number=5, port='A') ##-> Show the last 5 pulses send through on port A
switch.set_output_voltage(5) ## -> Set the output pulse voltage to 5V

# switch.connect(port='A', contact=1) ## Connect contact 1 of port A to the common terminal
# switch.disconnect(port='A', contact=1) ## Disconnects contact 1 of port A from the common terminal
# Out:
# Connected to LABPHOX, IP: 192.168.0.117, SerialN: SN34, Channels:2
# HW_Ver. 4 , FW_Ver. 5
# Initialization...
# Pulse duration set to 15 ms
# BIAS STATUS: Voltage set to -4.69V
# CONVERTER STATUS: Voltage set to 4.92V
# BIAS STATUS: Voltage set to -4.69V
# CONVERTER STATUS: Voltage set to 4.9V
# POWER STATUS: Ready
# Disconnect-> Port:A-3, Tue Aug-08 22:59:32PM
# Disconnect-> Port:A-4, Tue Aug-08 22:59:33PM
# Disconnect-> Port:A-5, Tue Aug-08 22:59:33PM
# Disconnect-> Port:A-6, Tue Aug-08 22:59:33PM
# Connect   -> Port:A-2, Tue Aug-08 22:59:35PM Warnings: Low current detected!
# Disconnect-> Port:B-3, Tue Aug-08 22:59:34PM
# Disconnect-> Port:B-4, Tue Aug-08 22:59:34PM
# Disconnect-> Port:B-5, Tue Aug-08 22:59:34PM
# Disconnect-> Port:B-6, Tue Aug-08 22:59:35PM
# Connect   -> Port:B-2, Tue Aug-08 22:59:35PM Warnings: Low current detected!
# BIAS STATUS: Voltage set to -4.7V
# CONVERTER STATUS: Voltage set to 4.91V
# Connected to LABPHOX, IP: 192.168.0.117, SerialN: SN34, Channels:2
# HW_Ver. 4 , FW_Ver. 5
# Initialization...
# Pulse duration set to 15 ms
# BIAS STATUS: Voltage set to -4.7V
# CONVERTER STATUS: Voltage set to 4.97V
# BIAS STATUS: Voltage set to -4.69V
# CONVERTER STATUS: Voltage set to 4.98V
# POWER STATUS: Ready
# Disconnect-> Port:A-3, Tue Aug-08 22:59:32PM
# Disconnect-> Port:A-4, Tue Aug-08 22:59:33PM
# Disconnect-> Port:A-5, Tue Aug-08 22:59:33PM
# Disconnect-> Port:A-6, Tue Aug-08 22:59:33PM
# Connect   -> Port:A-2, Tue Aug-08 22:59:35PM Warnings: Low current detected!
# BIAS STATUS: Voltage set to -4.69V
# CONVERTER STATUS: Voltage set to 4.92V
# 4.92
