# %%
import src.DataAnalysis as DataAnalysis
import src.DataHandler as DataHandler
import src.DataProcessor as DataProcessor
import src.ResonatorMeasurement as ResonatorMeasurement

# %%
# initialize instruments and load them into InstrConfig (or vice versa?) 
from src.BaseConfigs import InstrConfig
 
#  Test Tone -> anritsu signal generator
#  TWPA pump -> anritsu signal generator
#  VNA -> keysight PNA
#  SA -> R&S FSEB-20 (correct name?)

TWPA_Pump = InstrConfig()
TestTone = InstrConfig()
VNAobj = InstrConfig()
SpectrAnlyzer = InstrConfig()

AllInstruments = {
    "TWPA_Pump" : TWPA_Pump,
    "TestTone" : TestTone,
    "VNA" : VNAobj,
    "SpectrumAnalyzer" : SpectrAnlyzer,
}

# %%
# define experiment parameters, create ExptConfig
from src.BaseConfigs import ExptConfig

#   static variables
#       VNA -> span, power
#       
#   sweep variables
#       TWPA pump -> ampl/freq
#

BaseConfig = {
}

SingleSweep_SingleRes_Init = {
    **BaseConfig,
    "" : "",
} 

SingleSweep_ManyRes_Init = {
    **BaseConfig,
    "" : ""
}

ManySweep_SingleRes_Init = {
    **BaseConfig,
    "" : ""
}

ManySweep_ManyRes_Init = {
    **BaseConfig,
    "" : ""
}

# %%
# ResonatorMeasurement experiment object, load configs

# %%
# run ResonatorMeasurement for a single sweep of a single resonator
SingleSweep_SingleRes = ExptConfig(AllInstruments, SingleSweep_SingleRes_Init)

# %%
# run ResonatorMeasurement for a power sweep of a single resonator
SingleSweep_ManyRes = ExptConfig(AllInstruments, SingleSweep_ManyRes_Init)

# %%
# run ResonatorMeasurement for a single sweep of a many resonator
ManySweep_SingleRes = ExptConfig(AllInstruments, ManySweep_SingleRes_Init)

# %%
# run ResonatorMeasurement for a power sweep of a many resonator
ManySweep_ManyRes = ExptConfig(AllInstruments, ManySweep_ManyRes_Init)
